# %%
import matplotlib.gridspec as gridspec

def plot(header):
    colors = ['blue', 'green', 'red', 'cyan', 'magenta', 'yellow', 'orange', 'purple', 
              'brown', 'pink', 'gray', 'olive', 'teal', 'navy', 'lime', 'gold', 'violet', 'blue']
    all_dates = pd.date_range(start=df1['days'].min(), end=df1['days'].max())
    
    if header != 'time' and header != 'days':
        fig = plt.figure(figsize=(8, 6))
        gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1])  # 2 Zeilen, Plot 3/4 und Tabelle 1/4

        ax = plt.subplot(gs[0])  # Plot in der oberen Zeile
        
        # Plot der Daten
        x_values_per_day = df1.groupby('days')[header].sum()
        x_values_per_day = x_values_per_day.reindex(all_dates, fill_value=None)
        ax.plot(x_values_per_day, color=colors[df1.columns.get_loc(header)], label='Anzahl')

        # Zellen für die Tabelle
        x_values_per_hour = df1[header]
        cells_per_hour = [x_values_per_hour.mean(), x_values_per_hour.median(),
                          x_values_per_hour.std(), x_values_per_hour.min(), x_values_per_hour.max()]

        cells_per_day = [x_values_per_day.mean(), x_values_per_day.median(), 
                         x_values_per_day.std(), x_values_per_day.min(), x_values_per_day.max()]

        # Runde die Werte für die Tabelle
        cells_per_hour = [round(value, 2) for value in cells_per_hour]
        cells_per_day = [round(value, 2) for value in cells_per_day]

        # Tabellenüberschriften
        titles = ['Mittelwert', 'Median', 'Standardabw.', 'Min', 'Max']

        # Tabelle in der unteren Zeile
        ax_table = plt.subplot(gs[1])  # Leere Achse, um die Tabelle zu setzen
        ax_table.axis('off')  # Achsen ausschalten, da nur die Tabelle angezeigt wird

        # Tabelle erstellen
        table = ax_table.table(cellText=[cells_per_hour, cells_per_day], rowLabels=['pro Stunde', 'pro Tag'],
                               colLabels=titles, loc='center')
        table.auto_set_font_size(False)
        table.set_fontsize(10)
        table.scale(1, 1.5)

        # Achsentitel und Legende für den Plot
        ax.set_title(header)
        ax.set_xlabel('Tag')
        ax.set_ylabel('Überquerungen mit dem Fahrrad')
        ax.legend()

        # Plot anzeigen
        plt.tight_layout()
        plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as npy

df1: pd.DataFrame()

def iterate(filename):
    for name in filename.columns:
        plot(name)

# %%
import os
dataframes = []

for filename in os.listdir('../Projektdatensaetze/2015-2017'):
    if filename.endswith('.csv') and filename != 'standortinformationen_dauerzählsstellen.csv':
        print(filename)
        df: pd.DataFrame = pd.read_csv('../Projektdatensaetze/2015-2017/' + filename, sep=';|,')
        df1 = df.copy()
        df1 = df1.rename(columns={df1.columns[0]: 'time'})
        df1['time'] = pd.to_datetime(df1['time'], format='mixed')
        df1['days'] = df1['time'].dt.date
        dataframes.append(df1)
        #iterate(df1)
    else:
        continue

# %%
from functions import *

# %%
for df in dataframes:
    print_maxima(df)
# Out:
# 5.01 BN - Kennedybrücke (Nordseite)                             2016-11-29
# 5.01 BN - Kennedybrücke (Nordseite) Radfahrer Ri. Innenstadt    2015-04-15
# 5.01 BN - Kennedybrücke (Nordseite) Radfahrer Ri. Beuel         2017-01-06
# dtype: datetime64[ns]
# 5.02 BN - Kennedybrücke (Südseite) Barometer                       2017-05-17
# 5.02 BN - Kennedybrücke (Südseite) IN                              2017-05-17
# 5.02 BN - Kennedybrücke (Südseite) Barometer Radfahrer Ri. Beuel   2017-05-17
# dtype: datetime64[ns]
# 5.03 BN - Nordbrücke (Südseite)                          2015-06-04
# 5.03 BN - Nordbrücke (Südseite) Radfahrer Ri. Beuel      2015-08-30
# 5.03 BN - Nordbrücke (Südseite) Radfahrer Ri. Auerberg   2015-06-04
# dtype: datetime64[ns]
# 5.04 BN - Nordbrücke (Nordseite)                          2016-07-24
# 5.04 BN - Nordbrücke (Nordseite) Radfahrer Ri. Beuel      2016-07-24
# 5.04 BN - Nordbrücke (Nordseite) Radfahrer Ri. Auerberg   2016-07-24
# dtype: datetime64[ns]
# 5.06 BN - Südbrücke (Nordseite)                                2017-05-06
# 5.06 BN - Südbrücke (Nordseite) Radfahrer Ri. Gronau           2017-05-06
# 5.06 BN - Südbrücke (Nordseite) Radfahrer Ri. Ri. Ramersdorf   2017-05-06
# dtype: datetime64[ns]
# 5.05 BN - Südbrücke (Südseite)                            2017-08-23
# 5.05 BN - Südbrücke (Südseite) Radfahrer Ri. Gronau       2017-08-23
# 5.05 BN - Südbrücke (Südseite) Radfahrer Ri. Ramersdorf   2017-05-17
# dtype: datetime64[ns]
# 5.07 BN - Estermannufer                       2016-08-07
# 5.07 BN - Estermannufer Radfahrer Ri. Bonn    2016-08-07
# 5.07 BN - Estermannufer Radfahrer Ri. Köln    2016-08-07
# dtype: datetime64[ns]
# 5.08 BN - Von-Sandt-Ufer                                2015-06-04
# 5.08 BN - Von-Sandt-Ufer Radfahrer Ri. Bad Godesberg    2016-08-07
# 5.08 BN - Von-Sandt-Ufer Radfahrer Ri. Bonn             2015-06-04
# dtype: datetime64[ns]
# 5.09 BN - Rhenusallee                            2015-06-04
# 5.09 BN - Rhenusallee Radfahrer Ri. Beuel        2015-06-04
# 5.09 BN - Rhenusallee Radfahrer Ri. Oberkassel   2016-05-07
# dtype: datetime64[ns]
# 5.11 BN - Brühler Straße                        2017-06-20
# 5.11 BN - Brühler Straße Radfahrer Ri. Süden    2017-06-20
# 5.11 BN - Brühler Straße Radfahrer Ri. Norden   2017-06-01
# dtype: datetime64[ns]
# 5.12 BN - Straßburger Weg                          2016-07-07
# 5.12 BN - Straßenburger Weg Radfahrer Ri. Süden    2017-10-19
# 5.12 BN - Straßenburger Weg Radfahrer Ri. Norden   2015-06-16
# dtype: datetime64[ns]
# 5.13 BN - Wilhelm-Spiritus-Ufer                           2016-05-07
# 5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Süden       2016-08-07
# 5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Norden      2016-05-07
# 5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Süden .1    2016-05-08
# 5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Norden .1   2016-05-07
# 5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Süden .2    2016-01-16
# 5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Norden      2016-01-16
# dtype: datetime64[ns]
# 5.14 BN - Mc Cloy Weg                            2016-08-07
# 5.14 BN - Mc Cloy Weg Radfahrer Ri. Remagen      2016-08-07
# 5.14 BN - Mc Cloy Weg Radfahrer Ri. Bonn         2016-06-05
# 5.14 BN - Mc Cloy Weg Radfahrer Ri. Remagen .1   2017-07-09
# 5.14 BN - Mc Cloy Weg Radfahrer Ri. Bonn         2016-08-07
# dtype: datetime64[ns]
# 5.15 BN - Weg auf Damm Neil                           2016-05-05
# 5.15 BN - Weg auf Damm Neil Radfahrer Ri. Norden      2016-05-05
# 5.15 BN - Weg auf Damm Neil Radfahrer Ri. Süden       2016-05-07
# 5.15 BN - Weg auf Damm Neil Radfahrer Ri. Norden .1   2016-05-08
# 5.15 BN - Weg auf Damm Neil Radfahrer Ri. Süden       2016-05-07
# dtype: datetime64[ns]

# %%
for df in dataframes:
    all_dates = pd.date_range(start=df['days'].min(), end=df['days'].max())
    columns = df.columns[1: len(df.columns) - 1]
    x_values_per_day = df.groupby('days', dropna=False)[columns].agg(lambda x: x.sum(skipna=False))
    x_values_per_day = x_values_per_day.reindex(all_dates, fill_value=None)
    pd.set_option('display.max_colwidth', None)
    null_mask = x_values_per_day.isnull().any(axis=1)
    null_rows = x_values_per_day[null_mask]
    length = len(x_values_per_day.columns)
    keys = x_values_per_day.columns[1:length - 1]
    nulls = []
    groups = df.groupby('days')
    for column in x_values_per_day.columns:
        null_crossings = []
        values = [name for name, gruppe in groups if gruppe[column].isnull().all()]
        null_crossings.append(column)
        null_crossings.append(values)
        nulls.append(null_crossings)
    display(nulls)
# Out:
# [['5.01 BN - Kennedybrücke (Nordseite) ', []],
#  ['5.01 BN - Kennedybrücke (Nordseite) Radfahrer Ri. Innenstadt ', []],
#  ['5.01 BN - Kennedybrücke (Nordseite) Radfahrer Ri. Beuel', []]]
# [['5.02 BN - Kennedybrücke (Südseite) Barometer ', []],
#  ['5.02 BN - Kennedybrücke (Südseite) IN ', []],
#  ['5.02 BN - Kennedybrücke (Südseite) Barometer Radfahrer Ri. Beuel', []]]
# [['5.03 BN - Nordbrücke (Südseite) ', []],
#  ['5.03 BN - Nordbrücke (Südseite) Radfahrer Ri. Beuel ', []],
#  ['5.03 BN - Nordbrücke (Südseite) Radfahrer Ri. Auerberg', []]]
# [['5.04 BN - Nordbrücke (Nordseite) ', []],
#  ['5.04 BN - Nordbrücke (Nordseite) Radfahrer Ri. Beuel ', []],
#  ['5.04 BN - Nordbrücke (Nordseite) Radfahrer Ri. Auerberg', []]]
# [['5.06 BN - Südbrücke (Nordseite) ', []],
#  ['5.06 BN - Südbrücke (Nordseite) Radfahrer Ri. Gronau ', []],
#  ['5.06 BN - Südbrücke (Nordseite) Radfahrer Ri. Ri. Ramersdorf', []]]
# [['5.05 BN - Südbrücke (Südseite) ', []],
#  ['5.05 BN - Südbrücke (Südseite) Radfahrer Ri. Gronau ', []],
#  ['5.05 BN - Südbrücke (Südseite) Radfahrer Ri. Ramersdorf', []]]
# [['5.07 BN - Estermannufer ', []],
#  ['5.07 BN - Estermannufer Radfahrer Ri. Bonn ', []],
#  ['5.07 BN - Estermannufer Radfahrer Ri. Köln', []]]
# [['5.08 BN - Von-Sandt-Ufer ', []],
#  ['5.08 BN - Von-Sandt-Ufer Radfahrer Ri. Bad Godesberg ', []],
#  ['5.08 BN - Von-Sandt-Ufer Radfahrer Ri. Bonn', []]]
# [['5.09 BN - Rhenusallee ', []],
#  ['5.09 BN - Rhenusallee Radfahrer Ri. Beuel ', []],
#  ['5.09 BN - Rhenusallee Radfahrer Ri. Oberkassel', []]]
# [['5.11 BN - Brühler Straße ', []],
#  ['5.11 BN - Brühler Straße Radfahrer Ri. Süden ', []],
#  ['5.11 BN - Brühler Straße Radfahrer Ri. Norden', []]]
# [['5.12 BN - Straßburger Weg ', []],
#  ['5.12 BN - Straßenburger Weg Radfahrer Ri. Süden ', []],
#  ['5.12 BN - Straßenburger Weg Radfahrer Ri. Norden', []]]
# [['5.13 BN - Wilhelm-Spiritus-Ufer ', []],
#  ['5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Süden ', []],
#  ['5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Norden ', []],
#  ['5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Süden .1', []],
#  ['5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Norden .1', []],
#  ['5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Süden .2', []],
#  ['5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Norden', []]]
# [['5.14 BN - Mc Cloy Weg ', []],
#  ['5.14 BN - Mc Cloy Weg Radfahrer Ri. Remagen ', []],
#  ['5.14 BN - Mc Cloy Weg Radfahrer Ri. Bonn ', []],
#  ['5.14 BN - Mc Cloy Weg Radfahrer Ri. Remagen .1', []],
#  ['5.14 BN - Mc Cloy Weg Radfahrer Ri. Bonn', []]]
# [['5.15 BN - Weg auf Damm Neil ', []],
#  ['5.15 BN - Weg auf Damm Neil Radfahrer Ri. Norden ', []],
#  ['5.15 BN - Weg auf Damm Neil Radfahrer Ri. Süden ', []],
#  ['5.15 BN - Weg auf Damm Neil Radfahrer Ri. Norden .1', []],
#  ['5.15 BN - Weg auf Damm Neil Radfahrer Ri. Süden', []]]

# %%
for df in dataframes:
    all_dates = pd.date_range(start=df['days'].min(), end=df['days'].max())
    columns = df.columns[1: len(df.columns) - 1]
    x_values_per_day = df.groupby('days', dropna=False)[columns].agg(lambda x: x.sum(skipna=False))
    x_values_per_day = x_values_per_day.reindex(all_dates, fill_value=None)
    length=len(x_values_per_day.columns)
    #keys= x_values_per_day.columns[1:length-1]
    #cols = (x_values_per_day == 0).any()
    #zero_days = x_values_per_day.loc[:,cols]
    zeros = []
    groups = df.groupby('days')
    for column in x_values_per_day.columns:
        zero_crossings = []
        values = [name for name, gruppe in groups if (gruppe[column] == 0).all()]
        zero_crossings.append(column)
        zero_crossings.append(values)
        zeros.append(zero_crossings)
    print(zeros)
# Out:
# [['5.01 BN - Kennedybrücke (Nordseite) ', []], ['5.01 BN - Kennedybrücke (Nordseite) Radfahrer Ri. Innenstadt ', []], ['5.01 BN - Kennedybrücke (Nordseite) Radfahrer Ri. Beuel', []]]
# [['5.02 BN - Kennedybrücke (Südseite) Barometer ', []], ['5.02 BN - Kennedybrücke (Südseite) IN ', []], ['5.02 BN - Kennedybrücke (Südseite) Barometer Radfahrer Ri. Beuel', []]]
# [['5.03 BN - Nordbrücke (Südseite) ', [datetime.date(2016, 5, 24), datetime.date(2016, 5, 25), datetime.date(2016, 6, 1), datetime.date(2016, 6, 12), datetime.date(2016, 6, 13), datetime.date(2016, 6, 14), datetime.date(2016, 6, 16), datetime.date(2016, 6, 17), datetime.date(2016, 6, 18), datetime.date(2016, 6, 21), datetime.date(2016, 6, 27), datetime.date(2016, 7, 10), datetime.date(2016, 7, 11), datetime.date(2016, 7, 13), datetime.date(2016, 7, 14), datetime.date(2016, 7, 15), datetime.date(2016, 7, 17), datetime.date(2016, 7, 18), datetime.date(2016, 7, 19), datetime.date(2016, 7, 20), datetime.date(2016, 7, 22), datetime.date(2016, 7, 23), datetime.date(2016, 7, 24), datetime.date(2016, 7, 25), datetime.date(2016, 7, 26), datetime.date(2016, 7, 27), datetime.date(2016, 7, 29), datetime.date(2016, 7, 30), datetime.date(2016, 7, 31), datetime.date(2016, 8, 1), datetime.date(2017, 12, 7)]], ['5.03 BN - Nordbrücke (Südseite) Radfahrer Ri. Beuel ', [datetime.date(2016, 5, 24), datetime.date(2016, 5, 25), datetime.date(2016, 6, 1), datetime.date(2016, 6, 11), datetime.date(2016, 6, 12), datetime.date(2016, 6, 13), datetime.date(2016, 6, 14), datetime.date(2016, 6, 16), datetime.date(2016, 6, 17), datetime.date(2016, 6, 18), datetime.date(2016, 6, 21), datetime.date(2016, 6, 27), datetime.date(2016, 7, 9), datetime.date(2016, 7, 10), datetime.date(2016, 7, 11), datetime.date(2016, 7, 12), datetime.date(2016, 7, 13), datetime.date(2016, 7, 14), datetime.date(2016, 7, 15), datetime.date(2016, 7, 17), datetime.date(2016, 7, 18), datetime.date(2016, 7, 19), datetime.date(2016, 7, 20), datetime.date(2016, 7, 22), datetime.date(2016, 7, 23), datetime.date(2016, 7, 24), datetime.date(2016, 7, 25), datetime.date(2016, 7, 26), datetime.date(2016, 7, 27), datetime.date(2016, 7, 29), datetime.date(2016, 7, 30), datetime.date(2016, 7, 31), datetime.date(2016, 8, 1), datetime.date(2016, 8, 2), datetime.date(2017, 12, 6), datetime.date(2017, 12, 7)]], ['5.03 BN - Nordbrücke (Südseite) Radfahrer Ri. Auerberg', [datetime.date(2016, 5, 24), datetime.date(2016, 5, 25), datetime.date(2016, 5, 27), datetime.date(2016, 5, 30), datetime.date(2016, 6, 1), datetime.date(2016, 6, 2), datetime.date(2016, 6, 12), datetime.date(2016, 6, 13), datetime.date(2016, 6, 14), datetime.date(2016, 6, 15), datetime.date(2016, 6, 16), datetime.date(2016, 6, 17), datetime.date(2016, 6, 18), datetime.date(2016, 6, 20), datetime.date(2016, 6, 21), datetime.date(2016, 6, 22), datetime.date(2016, 6, 27), datetime.date(2016, 6, 30), datetime.date(2016, 7, 1), datetime.date(2016, 7, 3), datetime.date(2016, 7, 5), datetime.date(2016, 7, 10), datetime.date(2016, 7, 11), datetime.date(2016, 7, 13), datetime.date(2016, 7, 14), datetime.date(2016, 7, 15), datetime.date(2016, 7, 16), datetime.date(2016, 7, 17), datetime.date(2016, 7, 18), datetime.date(2016, 7, 19), datetime.date(2016, 7, 20), datetime.date(2016, 7, 21), datetime.date(2016, 7, 22), datetime.date(2016, 7, 23), datetime.date(2016, 7, 24), datetime.date(2016, 7, 25), datetime.date(2016, 7, 26), datetime.date(2016, 7, 27), datetime.date(2016, 7, 28), datetime.date(2016, 7, 29), datetime.date(2016, 7, 30), datetime.date(2016, 7, 31), datetime.date(2016, 8, 1), datetime.date(2017, 12, 7)]]]
# [['5.04 BN - Nordbrücke (Nordseite) ', [datetime.date(2017, 12, 1), datetime.date(2017, 12, 4)]], ['5.04 BN - Nordbrücke (Nordseite) Radfahrer Ri. Beuel ', [datetime.date(2017, 12, 1), datetime.date(2017, 12, 2), datetime.date(2017, 12, 3), datetime.date(2017, 12, 4)]], ['5.04 BN - Nordbrücke (Nordseite) Radfahrer Ri. Auerberg', [datetime.date(2017, 12, 1), datetime.date(2017, 12, 4)]]]
# [['5.06 BN - Südbrücke (Nordseite) ', []], ['5.06 BN - Südbrücke (Nordseite) Radfahrer Ri. Gronau ', []], ['5.06 BN - Südbrücke (Nordseite) Radfahrer Ri. Ri. Ramersdorf', []]]
# [['5.05 BN - Südbrücke (Südseite) ', []], ['5.05 BN - Südbrücke (Südseite) Radfahrer Ri. Gronau ', []], ['5.05 BN - Südbrücke (Südseite) Radfahrer Ri. Ramersdorf', []]]
# [['5.07 BN - Estermannufer ', []], ['5.07 BN - Estermannufer Radfahrer Ri. Bonn ', []], ['5.07 BN - Estermannufer Radfahrer Ri. Köln', []]]
# [['5.08 BN - Von-Sandt-Ufer ', []], ['5.08 BN - Von-Sandt-Ufer Radfahrer Ri. Bad Godesberg ', []], ['5.08 BN - Von-Sandt-Ufer Radfahrer Ri. Bonn', []]]
# [['5.09 BN - Rhenusallee ', []], ['5.09 BN - Rhenusallee Radfahrer Ri. Beuel ', []], ['5.09 BN - Rhenusallee Radfahrer Ri. Oberkassel', []]]
# [['5.11 BN - Brühler Straße ', []], ['5.11 BN - Brühler Straße Radfahrer Ri. Süden ', []], ['5.11 BN - Brühler Straße Radfahrer Ri. Norden', []]]
# [['5.12 BN - Straßburger Weg ', []], ['5.12 BN - Straßenburger Weg Radfahrer Ri. Süden ', []], ['5.12 BN - Straßenburger Weg Radfahrer Ri. Norden', []]]
# [['5.13 BN - Wilhelm-Spiritus-Ufer ', []], ['5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Süden ', []], ['5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Norden ', []], ['5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Süden .1', []], ['5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Norden .1', []], ['5.13 BN - Wilhelm-Spiritus-Ufer Radfahrer Ri. Süden .2', [datetime.date(2016, 1, 16), datetime.date(2016, 1, 17), datetime.date(2016, 1, 18), datetime.date(2016, 1, 19), datetime.date(2016, 1, 20), datetime.date(2016, 1, 21), datetime.date(2016, 1, 22), datetime.date(2016, 1, 23), datetime.date(2016, 1, 24), datetime.date(2016, 1, 25), datetime.date(2016, 1, 26), datetime.date(2016, 1, 27), datetime.date(2016, 1, 28), datetime.date(2016, 1, 29), datetime.date(2016, 1, 30), datetime.date(2016, 1, 31), datetime.date(2016, 2, 1), datetime.date(2016, 2, 2), datetime.date(2016, 2, 3), datetime.date(2016, 2, 4), datetime.date(2016, 2, 5), datetime.date(2016, 2, 6), datetime.date(2016, 2, 7), datetime.date(2016, 2, 8), datetime.date(2016, 2, 9), datetime.date(2016, 2, 10), datetime.date(2016, 2, 11), datetime.date(2016, 2, 12), datetime.date(2016, 2, 13), datetime.date(2016, 2, 14), datetime.date(2016, 2, 15), datetime.date(2016, 2, 16), datetime.date(2016, 2, 17), datetime.date(2016, 2, 18), datetime.date(2016, 2, 19), datetime.date(2016, 2, 20), datetime.date(2016, 2, 21), datetime.date(2016, 2, 22), datetime.date(2016, 2, 23), datetime.date(2016, 2, 24), datetime.date(2016, 2, 25), datetime.date(2016, 2, 26), datetime.date(2016, 2, 27), datetime.date(2016, 2, 28), datetime.date(2016, 2, 29), datetime.date(2016, 3, 1), datetime.date(2016, 3, 2), datetime.date(2016, 3, 3), datetime.date(2016, 3, 4), datetime.date(2016, 3, 5), datetime.date(2016, 3, 6), datetime.date(2016, 3, 7), datetime.date(2016, 3, 8), datetime.date(2016, 3, 9), datetime.date(2016, 3, 10), datetime.date(2016, 3, 11), datetime.date(2016, 3, 12), datetime.date(2016, 3, 13), datetime.date(2016, 3, 14), datetime.date(2016, 3, 15), datetime.date(2016, 3, 16), datetime.date(2016, 3, 17), datetime.date(2016, 3, 18), datetime.date(2016, 3, 19), datetime.date(2016, 3, 20), datetime.date(2016, 3, 21), datetime.date(2016, 3, 22), datetime.date(2016, 3, 23), datetime.date(2016, 3, 24), datetime.date(2016, 3, 25), datetime.date(2016, 3, 26), datetime.date(2016, 3, 27), datetime.date(2016, 3, 28), datetime.date(2016, 3, 29), datetime.date(2016, 3, 30), datetime.date(2016, 3, 31), datetime.date(2016, 4, 1), datetime.date(2016, 4, 2), datetime.date(2016, 4, 3), datetime.date(2016, 4, 4), datetime.date(2016, 4, 5), datetime.date(2016, 4, 6), datetime.date(2016, 4, 7), datetime.date(2016, 4, 8), datetime.date(2016, 4, 9), datetime.date(2016, 4, 10), datetime.date(2016, 4, 11), datetime.date(2016, 4, 12), datetime.date(2016, 4, 13), datetime.date(2016, 4, 14), datetime.date(2016, 4, 15), datetime.date(2016, 4, 16), datetime.date(2016, 4, 17), datetime.date(2016, 4, 18), datetime.date(2016, 4, 19), datetime.date(2016, 4, 20), datetime.date(2016, 4, 21), datetime.date(2016, 4, 22), datetime.date(2016, 4, 23), datetime.date(2016, 4, 24), datetime.date(2016, 4, 25), datetime.date(2016, 4, 26), datetime.date(2016, 4, 27), datetime.date(2016, 4, 28), datetime.date(2016, 4, 29), datetime.date(2016, 4, 30), datetime.date(2016, 5, 1), datetime.date(2016, 5, 2), datetime.date(2016, 5, 3), datetime.date(2016, 5, 4), datetime.date(2016, 5, 5), datetime.date(2016, 5, 6), datetime.date(2016, 5, 7), datetime.date(2016, 5, 8), datetime.date(2016, 5, 9), datetime.date(2016, 5, 10), datetime.date(2016, 5, 11), datetime.date(2016, 5, 12), datetime.date(2016, 5, 13), datetime.date(2016, 5, 14), datetime.date(2016, 5, 15), datetime.date(2016, 5, 16), datetime.date(2016, 5, 17), datetime.date(2016, 5, 18), datetime.date(2016, 5, 19), datetime.date(2016, 5, 20), datetime.date(2016, 5, 21), datetime.date(2016, 5, 22), datetime.date(2016, 5, 23), datetime.date(2016, 5, 24), datetime.date(2016, 5, 25), datetime.da ...
# [['5.14 BN - Mc Cloy Weg ', [datetime.date(2016, 2, 11), datetime.date(2016, 2, 12), datetime.date(2016, 6, 1), datetime.date(2017, 12, 15), datetime.date(2017, 12, 16), datetime.date(2017, 12, 17)]], ['5.14 BN - Mc Cloy Weg Radfahrer Ri. Remagen ', [datetime.date(2016, 2, 11), datetime.date(2016, 2, 12), datetime.date(2016, 6, 1), datetime.date(2016, 6, 17), datetime.date(2016, 6, 18), datetime.date(2016, 6, 19), datetime.date(2016, 6, 20), datetime.date(2016, 6, 21), datetime.date(2017, 12, 15), datetime.date(2017, 12, 16), datetime.date(2017, 12, 17)]], ['5.14 BN - Mc Cloy Weg Radfahrer Ri. Bonn ', [datetime.date(2016, 2, 11), datetime.date(2016, 2, 12), datetime.date(2016, 6, 1), datetime.date(2016, 6, 17), datetime.date(2016, 6, 18), datetime.date(2016, 6, 20), datetime.date(2016, 6, 21), datetime.date(2017, 12, 15), datetime.date(2017, 12, 16), datetime.date(2017, 12, 17)]], ['5.14 BN - Mc Cloy Weg Radfahrer Ri. Remagen .1', [datetime.date(2016, 2, 11), datetime.date(2016, 2, 12), datetime.date(2016, 6, 1), datetime.date(2017, 12, 15), datetime.date(2017, 12, 16), datetime.date(2017, 12, 17), datetime.date(2017, 12, 20)]], ['5.14 BN - Mc Cloy Weg Radfahrer Ri. Bonn', [datetime.date(2016, 2, 11), datetime.date(2016, 2, 12), datetime.date(2016, 6, 1), datetime.date(2017, 12, 15), datetime.date(2017, 12, 16), datetime.date(2017, 12, 17)]]]
# [['5.15 BN - Weg auf Damm Neil ', []], ['5.15 BN - Weg auf Damm Neil Radfahrer Ri. Norden ', []], ['5.15 BN - Weg auf Damm Neil Radfahrer Ri. Süden ', []], ['5.15 BN - Weg auf Damm Neil Radfahrer Ri. Norden .1', []], ['5.15 BN - Weg auf Damm Neil Radfahrer Ri. Süden', []]]
