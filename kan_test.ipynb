# %%
from kan import *
import torch
# create a KAN: 2D inputs, 1D output, and 5 hidden neurons. cubic spline (k=3), 5 grid intervals (grid=5).
model = KAN(width=[2,5,1], grid=5, k=3, seed=0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from kan import *
#       2 import torch
#       3 # create a KAN: 2D inputs, 1D output, and 5 hidden neurons. cubic spline (k=3), 5 grid intervals (grid=5).
#
# File ~/.cache/pypoetry/virtualenvs/projekt-tUfJ2JQm-py3.12/lib/python3.12/site-packages/kan/__init__.py:1
# ----> 1 from .MultKAN import *
#       2 from .utils import *
#       3 #torch.use_deterministic_algorithms(True)
#
# File ~/.cache/pypoetry/virtualenvs/projekt-tUfJ2JQm-py3.12/lib/python3.12/site-packages/kan/MultKAN.py:4
#       2 import torch.nn as nn
#       3 import numpy as np
# ----> 4 from .KANLayer import KANLayer
#       5 #from .Symbolic_MultKANLayer import *
#       6 from .Symbolic_KANLayer import Symbolic_KANLayer
#
# File ~/.cache/pypoetry/virtualenvs/projekt-tUfJ2JQm-py3.12/lib/python3.12/site-packages/kan/KANLayer.py:5
#       3 import numpy as np
#       4 from .spline import *
# ----> 5 from .utils import sparse_mask
#       8 class KANLayer(nn.Module):
#       9     """
#      10     KANLayer class
#      11
#    (...)
#      41             device
#      42     """
#
# File ~/.cache/pypoetry/virtualenvs/projekt-tUfJ2JQm-py3.12/lib/python3.12/site-packages/kan/utils.py:3
#       1 import numpy as np
#       2 import torch
# ----> 3 from sklearn.linear_model import LinearRegression
#       4 import sympy
#       5 import yaml
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# create dataset f(x,y) = exp(sin(pi*x)+y^2)
f = lambda x: torch.exp(torch.sin(torch.pi*x[:,[0]]) + x[:,[1]]**2)
dataset = create_dataset(f, n_var=2)
dataset['train_input'].shape, dataset['train_label'].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 # create dataset f(x,y) = exp(sin(pi*x)+y^2)
#       2 f = lambda x: torch.exp(torch.sin(torch.pi*x[:,[0]]) + x[:,[1]]**2)
# ----> 3 dataset = create_dataset(f, n_var=2)
#       4 dataset['train_input'].shape, dataset['train_label'].shape
#
# NameError: name 'create_dataset' is not defined
